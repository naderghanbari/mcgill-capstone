# %% [markdown]
# <a href="https://colab.research.google.com/github/naderghanbari/mcgill-capstone/blob/master/capstone_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pylab as plt
import seaborn as sns
from IPython.display import HTML
from collections import namedtuple
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Load dataset
# In this step we load the data from 2015 to the end of 2019.

# %%
# Download the preprocessed dataset
# %%bash
mkdir -p data
curl https://storage.googleapis.com/capstone-data-lake/aggregated/indicents_crimes_date_division.csv --silent --output data/indicents_crimes_date_division.csv
echo Number of lines: `wc -l data/*`
# Out:
# Number of lines: 12265 data/indicents_crimes_date_division.csv

# %%
df = pd.read_csv("data/indicents_crimes_date_division.csv", parse_dates=["date"])

# Keep only dates in the [2015, 2019] range
df = df[df["date"].between("2015-01-01", "2019-12-31")]

# Convert type to Pandas date type
df["date"] = df["date"].dt.date
df.set_index("date", drop=True, inplace=True)
df.head()
# Out:
#             division  incidents  units_deployed  crimes
# date
# 2015-01-01         1         34              59       3
# 2015-01-01         2         81             140      15
# 2015-01-01         3         70             118       5
# 2015-01-01         4         70              92       8
# 2015-01-01         5         84             137      15

# %% [markdown]
# ### Split by division
# In this step we divide the dataset into chunks, one chunk
# per division.

# %%
# Split the data for each division
div_dfs = [y.drop(columns=["division"]) for _, y in df.groupby("division", as_index=False)]

# Function to display something for each division dataframe
def display_divs(what):
  for d, div in enumerate(div_dfs, start=1):
    display(HTML(f"<h2>Division {d}</h2>"))
    display(what(div))
    display(HTML("<hr />"))

# Print the head of all division dataframes
display_divs(lambda div: div.head())
# Out:
# <h2>Division 1</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         34              59       3
# 2015-01-02         33              42       6
# 2015-01-03         38              69       5
# 2015-01-04        128             176       4
# 2015-01-05         52              97       9
# <hr />
# <h2>Division 2</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         81             140      15
# 2015-01-02         59              86       9
# 2015-01-03         63             128      14
# 2015-01-04        206             270       4
# 2015-01-05         99             168      20
# <hr />
# <h2>Division 3</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         70             118       5
# 2015-01-02         61             104      15
# 2015-01-03         70             110      16
# 2015-01-04        130             180       8
# 2015-01-05         91             169      14
# <hr />
# <h2>Division 4</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         70              92       8
# 2015-01-02         87             107      11
# 2015-01-03         81             127      17
# 2015-01-04         79              94      11
# 2015-01-05        101             133      14
# <hr />
# <h2>Division 5</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         84             137      15
# 2015-01-02         69             200      12
# 2015-01-03         69             126      14
# 2015-01-04        106             168      10
# 2015-01-05         74             104      19
# <hr />
# <h2>Division 6</h2>
#             incidents  units_deployed  crimes
# date
# 2015-01-01         73             107      11
# 2015-01-02         34              72       9
# 2015-01-03         59             123      10
# 2015-01-04         59              95       6
# 2015-01-05         39              71      12
# <hr />

# %% [markdown]
# ### Statistics

# %%
# Print the descirption of all division dataframes
display_divs(lambda div: div.describe().transpose())
# Out:
# <h2>Division 1</h2>
#                  count       mean        std   min   25%   50%   75%    max
# incidents       1826.0  28.392662   8.292180  10.0  24.0  28.0  32.0  185.0
# units_deployed  1826.0  51.434283  19.697196  14.0  39.0  48.0  60.0  266.0
# crimes          1826.0   5.124315   2.843573   0.0   3.0   5.0   7.0   19.0
# <hr />
# <h2>Division 2</h2>
#                  count        mean        std   min    25%    50%    75%    max
# incidents       1826.0   56.756298  11.365715  30.0  50.00   56.0   62.0  206.0
# units_deployed  1826.0  103.976999  26.907707  50.0  86.25  100.0  116.0  360.0
# crimes          1826.0   10.957831   4.407450   1.0   8.00   11.0   14.0   38.0
# <hr />
# <h2>Division 3</h2>
#                  count        mean        std   min    25%    50%    75%    max
# incidents       1826.0   66.596386  12.428856  33.0   59.0   65.0   73.0  198.0
# units_deployed  1826.0  123.910186  30.175789  55.0  104.0  120.0  138.0  375.0
# crimes          1826.0   12.784228   4.837354   1.0    9.0   12.0   16.0   43.0
# <hr />
# <h2>Division 4</h2>
#                  count        mean        std   min    25%    50%    75%    max
# incidents       1826.0   66.627601  11.663707  32.0  59.00   66.0   73.0  195.0
# units_deployed  1826.0  104.811062  24.323615  41.0  88.25  102.0  117.0  256.0
# crimes          1826.0   14.150055   5.109587   2.0  11.00   14.0   17.0   58.0
# <hr />
# <h2>Division 5</h2>
#                  count        mean        std   min   25%    50%    75%    max
# incidents       1826.0   64.008762  11.003906  36.0  57.0   63.0   70.0  142.0
# units_deployed  1826.0  109.841731  26.101060  55.0  92.0  106.5  123.0  241.0
# crimes          1826.0   16.307229   5.727542   3.0  12.0   16.0   20.0   48.0
# <hr />
# <h2>Division 6</h2>
#                  count       mean        std   min   25%   50%   75%    max
# incidents       1826.0  45.500548   9.527595  18.0  39.0  45.0  51.0   93.0
# units_deployed  1826.0  84.541073  23.922333  31.0  69.0  81.0  96.0  242.0
# crimes          1826.0  11.776013   4.114085   2.0   9.0  11.0  14.0   33.0
# <hr />

# %% [markdown]
# ### Visualizations

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 200
plt.rcParams["figure.figsize"] = (20,2)

# Plot incidents and crimes for each division
for d, div in enumerate(div_dfs, start=1):
  div[["incidents", "crimes"]].plot(title=f"Division {d}");

# %% [markdown]
# # Test Training Split
# We'll use a sequential (70%, 20%, 10%) split for the training, inspired by
# [this TensorFlow example](https://www.tensorflow.org/tutorials/structured_data/time_series).

# %%
# Define a data structure for each dataset
Dataset = namedtuple(
  "Dataset", 
  field_names = ["name", "train", "val", "test"],
)

# Function to turn a dataframe to a dataset by splitting it
def to_dataset(df, name):
  n = len(df)
  return Dataset(
    name = name,  
    train = df[0:int(n*0.7)],
    val   = df[int(n*0.7):int(n*0.9)],
    test  = df[int(n*0.9):],
  )

# %%
# Split each division dataframe into training, validation, and test
div_datasets = [to_dataset(div, f"Division {d}") for d, div in enumerate(div_dfs, start=1)]

# %% [markdown]
# ### Normalization

# %%
# Define a data structure for a normalized dataset
# norm is the functional to normalize (base don the training dataset)
# denorm can be used to denormalize (inverse of the norm function)
NormalizedDataset = namedtuple(
  "NormalizedDataset", 
  field_names = ["name", "train", "val", "test", "norm", "denorm"],
)

# Normalize a dataset and return normalized train, val, test, tests along 
# with the function used to normalize and its inverse
def normalize(dataset):
  mean, std = dataset.train.mean(), dataset.train.std()
  norm = lambda df: (df - mean) / std
  return NormalizedDataset(
    name   = dataset.name,  
    train  = norm(dataset.train),
    val    = norm(dataset.val),
    test   = norm(dataset.test),
    norm   = norm,
    denorm = lambda df: df * std + mean,
  )

# %%
# Normalize all division datasets
div_norms = [normalize(ds) for ds in div_datasets]

# %% [markdown]
# ### Orignal vs. Normalized

# %%
# Renders a violin chart for a normalized dataset
def violin_chart(dataset, ylabel): 
  all = pd.concat([dataset.train, dataset.val, dataset.test])
  ticks = all.keys()
  all = all.melt(var_name="Feature", value_name=ylabel)
  ax = sns.violinplot(x="Feature", y=ylabel, data=all)
  ax.set_title(dataset.name)
  ax.set_xticklabels(ticks)
  plt.show()

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 120
plt.rcParams["figure.figsize"] = (4,2)

# Plot violin chart for each original division dataset
for ds in div_datasets:
  violin_chart(ds, ylabel="Original")

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 120
plt.rcParams["figure.figsize"] = (4,2)

# Plot violin chart for each normalized division dataset
for ds in div_norms:
  violin_chart(ds, ylabel="Normalized")

# %% [markdown]
# # Feature Engineering
# In this step we prepare the data by adding engineered time-based features such as a window in the past using Tensorflow Datasets api.
# This is inspired by [this official TensorFlow tutorial](https://www.tensorflow.org/tutorials/structured_data/time_series)

# %%
# Helper class that generates a time series dataset from the given
# raw Pandas dataset
class WindowGenerator():
  def __init__(self, dataset: NormalizedDataset, input_width: int, shift: int, label_width: int, label_columns: [str]):
    self.dataset = dataset
    self.label_columns = label_columns
    self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
    self.column_indices = {name: i for i, name in enumerate(dataset.train.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift
    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def split_window(self, features):
    inputs = features[:, self.input_slice, :]
    labels = features[:, self.labels_slice, :]
    if self.label_columns is not None:
      labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1
      )

    # Slicing doesn't preserve static shape information, so set the shapes
    # manually. This way the `tf.data.Datasets` are easier to inspect.
    inputs.set_shape([None, self.input_width, None])
    labels.set_shape([None, self.label_width, None])

    return inputs, labels

  def make_dataset(self, data):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=self.total_window_size,
        sequence_stride=1,
        shuffle=True,
        batch_size=32,
    )
    ds = ds.map(self.split_window)
    return ds

  def plot(self, plot_col, model=None, max_subplots=3, xlabel="Date"):
    inputs, labels = self.example
    plot_col_index = self.column_indices[plot_col]
    max_n = min(max_subplots, len(inputs))
    for n in range(max_n):
      plt.subplot(3, 1, n+1)
      plt.ylabel(plot_col)
      plt.plot(self.input_indices, inputs[n, :, plot_col_index], label="Inputs", marker=".", zorder=-10)
  
      if self.label_columns:
        label_col_index = self.label_columns_indices.get(plot_col, None)
      else:
        label_col_index = plot_col_index
  
      if label_col_index is None:
        continue

      plt.scatter(self.label_indices, labels[n, :, label_col_index], edgecolors='k', label='Labels', c='#2ca02c', s=64)
      if model is not None:
        predictions = model(inputs)
        plt.scatter(self.label_indices, predictions[n, :, label_col_index], marker='X', edgecolors='k', label='Predictions', c='#ff7f0e', s=64)
  
      if n == 0:
        plt.legend()

    plt.title(self.dataset.name)
    plt.xlabel(xlabel)

  @property
  def train(self):
    return self.make_dataset(self.dataset.train)

  @property
  def val(self):
    return self.make_dataset(self.dataset.val)

  @property
  def test(self):
    return self.make_dataset(self.dataset.test)

  @property
  def example(self):
    """Get and cache an example batch of `inputs, labels` for plotting."""
    result = getattr(self, '_example', None)
    if result is None:
      # No example batch was found, so get one from the `.train` dataset
      result = next(iter(self.train))
      # And cache it for next time
      self._example = result
    return result

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
# Division 1 windowing

div_1 = div_norms[0]

w1 = WindowGenerator(
  dataset = div_1  ,
  input_width=7, 
  shift=1,
  label_width=1, 
  label_columns=["incidents"],
)
w1
# Out:
# Total window size: 8
# Input indices: [0 1 2 3 4 5 6]
# Label indices: [7]
# Label column name(s): ['incidents']

# %% [markdown]
# ### Sample
# In this step we take a small sample from the dataset to
# double check the shape of the resulting window.

# %%
# Stack three slices, the length of the total window:
example_window = tf.stack([np.array(div_1.train[:w1.total_window_size]),
                           np.array(div_1.train[100:100+w1.total_window_size]),
                           np.array(div_1.train[200:200+w1.total_window_size])])


example_inputs, example_labels = w1.split_window(example_window)

print('All shapes are: (batch, time, features)')
print(f'Window shape: {example_window.shape}')
print(f'Inputs shape: {example_inputs.shape}')
print(f'labels shape: {example_labels.shape}')
# Out:
# All shapes are: (batch, time, features)
# Window shape: (3, 8, 3)
# Inputs shape: (3, 7, 3)
# labels shape: (3, 1, 1)

# %% [markdown]
# ### Sample Visualization
# In this step we see three sample windows.

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 100
plt.rcParams["figure.figsize"] = (12,6)

w1.plot(plot_col="incidents")

# %% [markdown]
# # Baseline models
# In this section we will create a baseline model for each division
# that simply predicts that there will use today's knowledge for tomorrow's
# prediction. In other words, the value of the target variable at next step
# is predicted exactly as the value of that column at the current step. For
# low frequency time series this is a reasonable baseline.

# %% [markdown]
# ### Baseline performance

# %%
# Function to create a single datastep for a dataset
def single_step_window(dataset):
  return WindowGenerator(
    dataset=dataset,
    input_width=1, 
    label_width=1, 
    shift=1,
    label_columns=["incidents"],
  )

# %%
# Create single step windows for all normalized division datasets
div_single_step_windows = [single_step_window(ds) for ds in div_norms]

# %%
# Baseline model
class Baseline(tf.keras.Model):
  def __init__(self, label_index=None):
    super().__init__()
    self.label_index = label_index

  def call(self, inputs):
    if self.label_index is None:
      return inputs
    result = inputs[:, :, self.label_index]
    return result[:, :, tf.newaxis]

# %%
# Define a data structure for performance metrics
class Perf(namedtuple("Perf", ["model", "val", "test", "history"])):
  def __repr__(self):
    return '\n'.join([
      f'Validation perf: {self.val}',
      f'Test perf: {self.test}',
    ])

def baseline_perf(window: WindowGenerator, label_column: str):
  baseline = Baseline(label_index=window.column_indices[label_column])
  baseline.compile(
    loss=tf.losses.MeanSquaredError(),
    metrics=[tf.metrics.MeanAbsoluteError()],
  )
  return Perf(
    model = baseline,  
    val   = baseline.evaluate(window.val),
    test  = baseline.evaluate(window.test, verbose=0),
    history = None,
  )

# %%
# Baseline performance for each division
baseline_perfs = [baseline_perf(w, label_column="incidents") for w in div_single_step_windows]
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3978 - mean_absolute_error: 0.9199
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2582 - mean_absolute_error: 0.8850
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4230 - mean_absolute_error: 0.9246
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3403 - mean_absolute_error: 1.1279
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3947 - mean_absolute_error: 0.9270
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4067 - mean_absolute_error: 0.9526

# %%
# Function to create a 7 days wide window for a dataset
def wide_window(dataset):
  return WindowGenerator(
    dataset=dataset,
    input_width=7, 
    label_width=7, 
    shift=1,
    label_columns=["incidents"],
  )

# %%
# Create wide windows for all normalized division datasets
div_wide_windows = [wide_window(ds) for ds in div_norms]

# %%
# Plot a sample prediction window
div_wide_windows[0].plot(model=baseline_perfs[0].model, plot_col="incidents")

# %% [markdown]
# ### Linear Model

# %%
# Function to compile, fit, and evaluate the performance of a model to a window
def compile_fit_eval(model: tf.keras.Model, window: WindowGenerator, patience: int=2, max_epochs: int = 20) -> Perf:
  early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=patience,
    mode="min",
  )

  model.compile(
    loss=tf.losses.MeanSquaredError(),
    optimizer=tf.optimizers.Adam(),
    metrics=[tf.metrics.MeanAbsoluteError()],
  )

  history = model.fit(
    window.train,
    epochs=max_epochs,
    validation_data=window.val,
    callbacks=[early_stopping],
  )
  
  return Perf(
    model = model,  
    val   = model.evaluate(window.val),
    test  = model.evaluate(window.test, verbose=0),
    history = history,
  )

# %%
# Creates a linear model, fits and evaluates its performance against the give window
def linear_fit_eval(window: WindowGenerator) -> Perf:
  return compile_fit_eval(
    model=tf.keras.Sequential([tf.keras.layers.Dense(units=1)]), 
    window=window,
  )

# %%
# Fit one linear models for each division
linear_perfs = [linear_fit_eval(w) for w in div_single_step_windows]
# Out:
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.8141 - mean_absolute_error: 1.0088 - val_loss: 1.4430 - val_mean_absolute_error: 0.9307
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7150 - mean_absolute_error: 0.9776 - val_loss: 1.3529 - val_mean_absolute_error: 0.8990
# Epoch 3/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.6273 - mean_absolute_error: 0.9492 - val_loss: 1.2736 - val_mean_absolute_error: 0.8697
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5502 - mean_absolute_error: 0.9232 - val_loss: 1.2034 - val_mean_absolute_error: 0.8422
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4819 - mean_absolute_error: 0.8991 - val_loss: 1.1438 - val_mean_absolute_error: 0.8178
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4224 - mean_absolute_error: 0.8775 - val_loss: 1.0925 - val_mean_absolute_error: 0.7966
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3694 - mean_absolute_error: 0.8574 - val_loss: 1.0481 - val_mean_absolute_error: 0.7778
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3228 - mean_absolute_error: 0.8397 - val_loss: 1.0090 - val_mean_absolute_error: 0.7610
# Epoch 9/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2810 - mean_absolute_error: 0.8234 - val_loss: 0.9749 - val_mean_absolute_error: 0.7460
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2438 - mean_absolute_error: 0.8086 - val_loss: 0.9452 - val_mean_absolute_error: 0.7328
# Epoch 11/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2105 - mean_absolute_error: 0.7952 - val_loss: 0.9204 - val_mean_absolute_error: 0.7217
# Epoch 12/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1809 - mean_absolute_error: 0.7830 - val_loss: 0.8979 - val_mean_absolute_error: 0.7109
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1542 - mean_absolute_error: 0.7717 - val_loss: 0.8794 - val_mean_absolute_error: 0.7024
# Epoch 14/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1302 - mean_absolute_error: 0.7610 - val_loss: 0.8637 - val_mean_absolute_error: 0.6960
# Epoch 15/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1087 - mean_absolute_error: 0.7518 - val_loss: 0.8499 - val_mean_absolute_error: 0.6906
# Epoch 16/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0895 - mean_absolute_error: 0.7431 - val_loss: 0.8378 - val_mean_absolute_error: 0.6861
# Epoch 17/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0724 - mean_absolute_error: 0.7355 - val_loss: 0.8282 - val_mean_absolute_error: 0.6826
# Epoch 18/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0572 - mean_absolute_error: 0.7284 - val_loss: 0.8191 - val_mean_absolute_error: 0.6789
# Epoch 19/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0438 - mean_absolute_error: 0.7223 - val_loss: 0.8129 - val_mean_absolute_error: 0.6775
# Epoch 20/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0318 - mean_absolute_error: 0.7164 - val_loss: 0.8076 - val_mean_absolute_error: 0.6763
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8076 - mean_absolute_error: 0.6763
# Epoch 1/20
# 40/40 [==============================] - 0s 6ms/step - loss: 3.1815 - mean_absolute_error: 1.3970 - val_loss: 2.6263 - val_mean_absolute_error: 1.2963
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.9721 - mean_absolute_error: 1.3504 - val_loss: 2.4461 - val_mean_absolute_error: 1.2499
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7835 - mean_absolute_error: 1.3061 - val_loss: 2.2815 - val_mean_absolute_error: 1.2067
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6118 - mean_absolute_error: 1.2645 - val_loss: 2.1335 - val_mean_absolute_error: 1.1664
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.4568 - mean_absolute_error: 1.2253 - val_loss: 1.9957 - val_mean_absolute_error: 1.1277
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.3152 - mean_absolute_error: 1.1878 - val_loss: 1.8720 - val_mean_absolute_error: 1.0926
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.1846 - mean_absolute_error: 1.1525 - val_loss: 1.7631 - val_mean_absolute_error: 1.0606
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.0675 - mean_absolute_error: 1.1191 - val_loss: 1.6629 - val_mean_absolute_error: 1.0305
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.9613 - mean_absolute_error: 1.0875 - val_loss: 1.5713 - val_mean_absolute_error: 1.0020
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.8649 - mean_absolute_error: 1.0579 - val_loss: 1.4900 - val_mean_absolute_error: 0.9762
# Epoch 11/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7769 - mean_absolute_error: 1.0298 - val_loss: 1.4188 - val_mean_absolute_error: 0.9527
# Epoch 12/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.6988 - mean_absolute_error: 1.0042 - val_loss: 1.3530 - val_mean_absolute_error: 0.9301
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6278 - mean_absolute_error: 0.9798 - val_loss: 1.2945 - val_mean_absolute_error: 0.9101
# Epoch 14/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.5635 - mean_absolute_error: 0.9568 - val_loss: 1.2439 - val_mean_absolute_error: 0.8922
# Epoch 15/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.5066 - mean_absolute_error: 0.9359 - val_loss: 1.1973 - val_mean_absolute_error: 0.8758
# Epoch 16/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.4549 - mean_absolute_error: 0.9163 - val_loss: 1.1572 - val_mean_absolute_error: 0.8615
# Epoch 17/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.4084 - mean_absolute_error: 0.8987 - val_loss: 1.1217 - val_mean_absolute_error: 0.8484
# Epoch 18/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.3667 - mean_absolute_error: 0.8827 - val_loss: 1.0904 - val_mean_absolute_error: 0.8362
# Epoch 19/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.3294 - mean_absolute_error: 0.8674 - val_loss: 1.0624 - val_mean_absolute_error: 0.8249
# Epoch 20/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2958 - mean_absolute_error: 0.8535 - val_loss: 1.0371 - val_mean_absolute_error: 0.8150
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0371 - mean_absolute_error: 0.8150
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 2.2138 - mean_absolute_error: 1.1044 - val_loss: 1.5817 - val_mean_absolute_error: 0.9771
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.0950 - mean_absolute_error: 1.0757 - val_loss: 1.5108 - val_mean_absolute_error: 0.9555
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.9911 - mean_absolute_error: 1.0492 - val_loss: 1.4501 - val_mean_absolute_error: 0.9369
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.8993 - mean_absolute_error: 1.0261 - val_loss: 1.3971 - val_mean_absolute_error: 0.9197
# Epoch 5/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.8169 - mean_absolute_error: 1.0045 - val_loss: 1.3495 - val_mean_absolute_error: 0.9041
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7436 - mean_absolute_error: 0.9850 - val_loss: 1.3076 - val_mean_absolute_error: 0.8911
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6776 - mean_absolute_error: 0.9666 - val_loss: 1.2709 - val_mean_absolute_error: 0.8802
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6183 - mean_absolute_error: 0.9502 - val_loss: 1.2378 - val_mean_absolute_error: 0.8703
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5653 - mean_absolute_error: 0.9355 - val_loss: 1.2071 - val_mean_absolute_error: 0.8608
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5159 - mean_absolute_error: 0.9213 - val_loss: 1.1830 - val_mean_absolute_error: 0.8526
# Epoch 11/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4726 - mean_absolute_error: 0.9081 - val_loss: 1.1580 - val_mean_absolute_error: 0.8443
# Epoch 12/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4322 - mean_absolute_error: 0.8957 - val_loss: 1.1369 - val_mean_absolute_error: 0.8367
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3957 - mean_absolute_error: 0.8844 - val_loss: 1.1183 - val_mean_absolute_error: 0.8297
# Epoch 14/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3625 - mean_absolute_error: 0.8738 - val_loss: 1.1008 - val_mean_absolute_error: 0.8234
# Epoch 15/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3317 - mean_absolute_error: 0.8643 - val_loss: 1.0856 - val_mean_absolute_error: 0.8176
# Epoch 16/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3041 - mean_absolute_error: 0.8558 - val_loss: 1.0720 - val_mean_absolute_error: 0.8122
# Epoch 17/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2784 - mean_absolute_error: 0.8481 - val_loss: 1.0597 - val_mean_absolute_error: 0.8076
# Epoch 18/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2550 - mean_absolute_error: 0.8409 - val_loss: 1.0489 - val_mean_absolute_error: 0.8037
# Epoch 19/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2342 - mean_absolute_error: 0.8340 - val_loss: 1.0382 - val_mean_absolute_error: 0.8002
# Epoch 20/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2138 - mean_absolute_error: 0.8276 - val_loss: 1.0290 - val_mean_absolute_error: 0.7972
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0290 - mean_absolute_error: 0.7972
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 2.8165 - mean_absolute_error: 1.2734 - val_loss: 3.2339 - val_mean_absolute_error: 1.3062
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6316 - mean_absolute_error: 1.2313 - val_loss: 3.0438 - val_mean_absolute_error: 1.2707
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.4664 - mean_absolute_error: 1.1924 - val_loss: 2.8701 - val_mean_absolute_error: 1.2363
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.3161 - mean_absolute_error: 1.1564 - val_loss: 2.7153 - val_mean_absolute_error: 1.2049
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 2.1805 - mean_absolute_error: 1.1227 - val_loss: 2.5758 - val_mean_absolute_error: 1.1762
# Epoch 6/20
# 40/40 [==============================] - 0s 6ms/step - loss: 2.0587 - mean_absolute_error: 1.0918 - val_loss: 2.4508 - val_mean_absolute_error: 1.1494
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.9488 - mean_absolute_error: 1.0639 - val_loss: 2.3413 - val_mean_absolute_error: 1.1262
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.8510 - mean_absolute_error: 1.0383 - val_loss: 2.2435 - val_mean_absolute_error: 1.1050
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7633 - mean_absolute_error: 1.0155 - val_loss: 2.1565 - val_mean_absolute_error: 1.0856
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6846 - mean_absolute_error: 0.9940 - val_loss: 2.0820 - val_mean_absolute_error: 1.0690
# Epoch 11/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6152 - mean_absolute_error: 0.9747 - val_loss: 2.0137 - val_mean_absolute_error: 1.0536
# Epoch 12/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5523 - mean_absolute_error: 0.9566 - val_loss: 1.9560 - val_mean_absolute_error: 1.0408
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4969 - mean_absolute_error: 0.9401 - val_loss: 1.9026 - val_mean_absolute_error: 1.0283
# Epoch 14/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4464 - mean_absolute_error: 0.9244 - val_loss: 1.8579 - val_mean_absolute_error: 1.0175
# Epoch 15/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4018 - mean_absolute_error: 0.9107 - val_loss: 1.8184 - val_mean_absolute_error: 1.0075
# Epoch 16/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3615 - mean_absolute_error: 0.8979 - val_loss: 1.7833 - val_mean_absolute_error: 0.9988
# Epoch 17/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3251 - mean_absolute_error: 0.8870 - val_loss: 1.7527 - val_mean_absolute_error: 0.9911
# Epoch 18/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2926 - mean_absolute_error: 0.8772 - val_loss: 1.7255 - val_mean_absolute_error: 0.9838
# Epoch 19/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2631 - mean_absolute_error: 0.8681 - val_loss: 1.7012 - val_mean_absolute_error: 0.9770
# Epoch 20/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2362 - mean_absolute_error: 0.8598 - val_loss: 1.6809 - val_mean_absolute_error: 0.9711
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6809 - mean_absolute_error: 0.9711
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.7408 - mean_absolute_error: 1.0373 - val_loss: 1.5162 - val_mean_absolute_error: 0.9529
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6698 - mean_absolute_error: 1.0156 - val_loss: 1.4613 - val_mean_absolute_error: 0.9349
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6037 - mean_absolute_error: 0.9957 - val_loss: 1.4112 - val_mean_absolute_error: 0.9203
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5431 - mean_absolute_error: 0.9768 - val_loss: 1.3648 - val_mean_absolute_error: 0.9068
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4878 - mean_absolute_error: 0.9589 - val_loss: 1.3225 - val_mean_absolute_error: 0.8941
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4365 - mean_absolute_error: 0.9420 - val_loss: 1.2846 - val_mean_absolute_error: 0.8825
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3893 - mean_absolute_error: 0.9255 - val_loss: 1.2506 - val_mean_absolute_error: 0.8725
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3464 - mean_absolute_error: 0.9106 - val_loss: 1.2179 - val_mean_absolute_error: 0.8626
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3065 - mean_absolute_error: 0.8961 - val_loss: 1.1897 - val_mean_absolute_error: 0.8544
# Epoch 10/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2703 - mean_absolute_error: 0.8831 - val_loss: 1.1639 - val_mean_absolute_error: 0.8474
# Epoch 11/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2371 - mean_absolute_error: 0.8706 - val_loss: 1.1397 - val_mean_absolute_error: 0.8407
# Epoch 12/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2068 - mean_absolute_error: 0.8593 - val_loss: 1.1187 - val_mean_absolute_error: 0.8350
# Epoch 13/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1786 - mean_absolute_error: 0.8485 - val_loss: 1.0996 - val_mean_absolute_error: 0.8295
# Epoch 14/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1535 - mean_absolute_error: 0.8385 - val_loss: 1.0815 - val_mean_absolute_error: 0.8243
# Epoch 15/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1304 - mean_absolute_error: 0.8292 - val_loss: 1.0661 - val_mean_absolute_error: 0.8199
# Epoch 16/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1097 - mean_absolute_error: 0.8205 - val_loss: 1.0523 - val_mean_absolute_error: 0.8157
# Epoch 17/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0909 - mean_absolute_error: 0.8125 - val_loss: 1.0390 - val_mean_absolute_error: 0.8115
# Epoch 18/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0737 - mean_absolute_error: 0.8053 - val_loss: 1.0286 - val_mean_absolute_error: 0.8082
# Epoch 19/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0587 - mean_absolute_error: 0.7989 - val_loss: 1.0173 - val_mean_absolute_error: 0.8044
# Epoch 20/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0448 - mean_absolute_error: 0.7927 - val_loss: 1.0089 - val_mean_absolute_error: 0.8016
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0089 - mean_absolute_error: 0.8016
# Epoch 1/20
# 40/40 [==============================] - 0s 6ms/step - loss: 2.1042 - mean_absolute_error: 1.1431 - val_loss: 2.1501 - val_mean_absolute_error: 1.1839
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.9610 - mean_absolute_error: 1.1043 - val_loss: 2.0168 - val_mean_absolute_error: 1.1477
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.8358 - mean_absolute_error: 1.0681 - val_loss: 1.8909 - val_mean_absolute_error: 1.1122
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7213 - mean_absolute_error: 1.0336 - val_loss: 1.7835 - val_mean_absolute_error: 1.0804
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.6224 - mean_absolute_error: 1.0033 - val_loss: 1.6859 - val_mean_absolute_error: 1.0511
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5346 - mean_absolute_error: 0.9759 - val_loss: 1.6004 - val_mean_absolute_error: 1.0248
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.4577 - mean_absolute_error: 0.9508 - val_loss: 1.5241 - val_mean_absolute_error: 1.0007
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3901 - mean_absolute_error: 0.9288 - val_loss: 1.4562 - val_mean_absolute_error: 0.9789
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.3316 - mean_absolute_error: 0.9088 - val_loss: 1.3939 - val_mean_absolute_error: 0.9577
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2791 - mean_absolute_error: 0.8906 - val_loss: 1.3415 - val_mean_absolute_error: 0.9395
# Epoch 11/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.2340 - mean_absolute_error: 0.8746 - val_loss: 1.2937 - val_mean_absolute_error: 0.9222
# Epoch 12/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1941 - mean_absolute_error: 0.8597 - val_loss: 1.2517 - val_mean_absolute_error: 0.9064
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1593 - mean_absolute_error: 0.8463 - val_loss: 1.2144 - val_mean_absolute_error: 0.8920
# Epoch 14/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1286 - mean_absolute_error: 0.8343 - val_loss: 1.1805 - val_mean_absolute_error: 0.8790
# Epoch 15/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1016 - mean_absolute_error: 0.8240 - val_loss: 1.1500 - val_mean_absolute_error: 0.8667
# Epoch 16/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0775 - mean_absolute_error: 0.8143 - val_loss: 1.1228 - val_mean_absolute_error: 0.8556
# Epoch 17/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0565 - mean_absolute_error: 0.8057 - val_loss: 1.0985 - val_mean_absolute_error: 0.8456
# Epoch 18/20
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0377 - mean_absolute_error: 0.7985 - val_loss: 1.0770 - val_mean_absolute_error: 0.8364
# Epoch 19/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0212 - mean_absolute_error: 0.7922 - val_loss: 1.0575 - val_mean_absolute_error: 0.8281
# Epoch 20/20
# 40/40 [==============================] - 0s 5ms/step - loss: 1.0067 - mean_absolute_error: 0.7864 - val_loss: 1.0395 - val_mean_absolute_error: 0.8203
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0395 - mean_absolute_error: 0.8203

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 80
plt.rcParams["figure.figsize"] = (10,8)

display(HTML(f"<h1>Linear Model Prediction Examples</h1>"))
div_wide_windows[0].plot(model=linear_perfs[0].model, plot_col="incidents")
# Out:
# <h1>Linear Model Prediction Examples</h1>

# %% [markdown]
# We see that the performance of the linear model is slightly better than the base line model for the evaluation set, but it performs very poorly on the test dataset.

# %%
# Function to display performance of each model for each division
def display_perfs(perfs):
  for d, perf in enumerate(perfs, start=1):
    display(HTML(f"<h2>Division {d}</h2>"))
    display(perf)
    display(HTML("<hr />"))

# %%
display(HTML(f"<h1>Linear Models Performance</h1>"))
display_perfs(linear_perfs)
# Out:
# <h1>Linear Models Performance</h1>
# <h2>Division 1</h2>
# Validation perf: [0.8075718283653259, 0.6762756705284119]
# Test perf: [2.903657913208008, 0.7663898468017578]
# <hr />
# <h2>Division 2</h2>
# Validation perf: [1.0370900630950928, 0.8149511218070984]
# Test perf: [2.062662363052368, 0.8684065937995911]
# <hr />
# <h2>Division 3</h2>
# Validation perf: [1.028971552848816, 0.7971787452697754]
# Test perf: [1.5924757719039917, 0.8362084627151489]
# <hr />
# <h2>Division 4</h2>
# Validation perf: [1.6809453964233398, 0.971123993396759]
# Test perf: [2.186800718307495, 0.966374397277832]
# <hr />
# <h2>Division 5</h2>
# Validation perf: [1.008880615234375, 0.801607072353363]
# Test perf: [1.3879164457321167, 0.8614580631256104]
# <hr />
# <h2>Division 6</h2>
# Validation perf: [1.0395478010177612, 0.820349395275116]
# Test perf: [0.927240788936615, 0.7440335750579834]
# <hr />

# %% [markdown]
# ### Visualize linear model weights

# %%
# Function to plot coeffieicnts of a linear model
def plot_lieanr_coeffs(window: WindowGenerator, perf: tf.keras.Model):
  plt.bar(
    x = range(len(window.dataset.train.columns)),
    height=perf.model.layers[0].kernel[:,0].numpy(),
  )
  axis = plt.gca()
  axis.set_xticks(range(len(window.dataset.train.columns)));
  axis.set_title(f"{window.dataset.name} Linear model coefficients")
  axis.set_xticklabels(window.dataset.train.columns);

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 120
plt.rcParams["figure.figsize"] = (4,2)

plot_lieanr_coeffs(div_single_step_windows[0], linear_perfs[0]);

# %%
plot_lieanr_coeffs(div_single_step_windows[1], linear_perfs[1]);

# %% [markdown]
# It's pretty clear that we should not
# invest more in a linear model. Sometimes, due to having random weights, the
# weight of the `incidents` column becomes close to zero or even negative which
# is very counter intuitive. Let's try more complex models now.

# %% [markdown]
# ## Single step DNN Regressor
# Before trying a wider window, let's try a more complex model on the
# same single step window, to see if complexity can help with predicting
# tomorrow's number of incidents by just knowing today's data.

# %%
# Creates a single-step DNN model, fits and evaluates its performance against the give window
def single_step_dnn_fit_eval(window: WindowGenerator) -> Perf:
  return compile_fit_eval(
    model=tf.keras.Sequential([
      tf.keras.layers.Dense(units=64, activation="relu"),
      tf.keras.layers.Dense(units=64, activation="relu"),
      tf.keras.layers.Dense(units=1),
    ]), 
    window=window,
  )

# %%
# Fit one single-step DNN models for each division
single_step_dnn_perfs = [single_step_dnn_fit_eval(w) for w in div_single_step_windows]
# Out:
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9709 - mean_absolute_error: 0.6818 - val_loss: 0.8366 - val_mean_absolute_error: 0.7010
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9544 - mean_absolute_error: 0.6784 - val_loss: 0.8467 - val_mean_absolute_error: 0.7102
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9514 - mean_absolute_error: 0.6769 - val_loss: 0.8242 - val_mean_absolute_error: 0.6929
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9474 - mean_absolute_error: 0.6764 - val_loss: 0.8227 - val_mean_absolute_error: 0.6898
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9454 - mean_absolute_error: 0.6713 - val_loss: 0.8489 - val_mean_absolute_error: 0.7111
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9499 - mean_absolute_error: 0.6740 - val_loss: 0.8375 - val_mean_absolute_error: 0.7014
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8375 - mean_absolute_error: 0.7014
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 0.9550 - mean_absolute_error: 0.6958 - val_loss: 0.7784 - val_mean_absolute_error: 0.7076
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9212 - mean_absolute_error: 0.6781 - val_loss: 0.7750 - val_mean_absolute_error: 0.7046
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9199 - mean_absolute_error: 0.6758 - val_loss: 0.7786 - val_mean_absolute_error: 0.7062
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9134 - mean_absolute_error: 0.6735 - val_loss: 0.7735 - val_mean_absolute_error: 0.7053
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9141 - mean_absolute_error: 0.6733 - val_loss: 0.7860 - val_mean_absolute_error: 0.7109
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9104 - mean_absolute_error: 0.6734 - val_loss: 0.7890 - val_mean_absolute_error: 0.7141
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7890 - mean_absolute_error: 0.7141
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9297 - mean_absolute_error: 0.7378 - val_loss: 0.9146 - val_mean_absolute_error: 0.7589
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9097 - mean_absolute_error: 0.7259 - val_loss: 0.8968 - val_mean_absolute_error: 0.7505
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9083 - mean_absolute_error: 0.7275 - val_loss: 0.9238 - val_mean_absolute_error: 0.7634
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9035 - mean_absolute_error: 0.7253 - val_loss: 0.8968 - val_mean_absolute_error: 0.7491
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8968 - mean_absolute_error: 0.7491
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9788 - mean_absolute_error: 0.7717 - val_loss: 1.4490 - val_mean_absolute_error: 0.8954
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9319 - mean_absolute_error: 0.7585 - val_loss: 1.4487 - val_mean_absolute_error: 0.8951
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9296 - mean_absolute_error: 0.7578 - val_loss: 1.4183 - val_mean_absolute_error: 0.8807
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9248 - mean_absolute_error: 0.7549 - val_loss: 1.4209 - val_mean_absolute_error: 0.8814
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9187 - mean_absolute_error: 0.7525 - val_loss: 1.4389 - val_mean_absolute_error: 0.8908
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4389 - mean_absolute_error: 0.8908
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9590 - mean_absolute_error: 0.7489 - val_loss: 0.9206 - val_mean_absolute_error: 0.7651
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9429 - mean_absolute_error: 0.7398 - val_loss: 0.9341 - val_mean_absolute_error: 0.7752
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9358 - mean_absolute_error: 0.7368 - val_loss: 0.9021 - val_mean_absolute_error: 0.7554
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9367 - mean_absolute_error: 0.7389 - val_loss: 0.9276 - val_mean_absolute_error: 0.7725
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9313 - mean_absolute_error: 0.7364 - val_loss: 0.9085 - val_mean_absolute_error: 0.7602
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9085 - mean_absolute_error: 0.7602
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9344 - mean_absolute_error: 0.7624 - val_loss: 0.9108 - val_mean_absolute_error: 0.7576
# Epoch 2/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.9126 - mean_absolute_error: 0.7544 - val_loss: 0.8905 - val_mean_absolute_error: 0.7468
# Epoch 3/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.9009 - mean_absolute_error: 0.7504 - val_loss: 0.8823 - val_mean_absolute_error: 0.7423
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8912 - mean_absolute_error: 0.7447 - val_loss: 0.8886 - val_mean_absolute_error: 0.7441
# Epoch 5/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8946 - mean_absolute_error: 0.7464 - val_loss: 0.8832 - val_mean_absolute_error: 0.7410
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8832 - mean_absolute_error: 0.7410

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 80
plt.rcParams["figure.figsize"] = (10,8)

display(HTML(f"<h1>Single Step DNN Prediction Examples</h1>"))
div_wide_windows[0].plot(model=single_step_dnn_perfs[0].model, plot_col="incidents")
# Out:
# <h1>Single Step DNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>Single Step DNN Performance</h1>"))
display_perfs(single_step_dnn_perfs)
# Out:
# <h1>Single Step DNN Performance</h1>
# <h2>Division 1</h2>
# Validation perf: [0.8375220894813538, 0.701425313949585]
# Test perf: [2.9399404525756836, 0.794075071811676]
# <hr />
# <h2>Division 2</h2>
# Validation perf: [0.7890220284461975, 0.714120626449585]
# Test perf: [1.8658658266067505, 0.7574653029441833]
# <hr />
# <h2>Division 3</h2>
# Validation perf: [0.8968415260314941, 0.7490970492362976]
# Test perf: [1.5377540588378906, 0.7898099422454834]
# <hr />
# <h2>Division 4</h2>
# Validation perf: [1.438923954963684, 0.8907914757728577]
# Test perf: [2.0149991512298584, 0.9160007238388062]
# <hr />
# <h2>Division 5</h2>
# Validation perf: [0.9085190296173096, 0.7601771950721741]
# Test perf: [1.240442156791687, 0.7944350242614746]
# <hr />
# <h2>Division 6</h2>
# Validation perf: [0.8831893801689148, 0.7410259246826172]
# Test perf: [0.7968840599060059, 0.6968985199928284]
# <hr />

# %% [markdown]
# It is clear that the hidden layers, even with a RELU activation function which
# together can capture non-linearity are performing almost as poor as a linear model. So as a next step let's widen the window and look at past 7 days.

# %% [markdown]
# ### Multistep DNN (7 days window)

# %%
# Function to create a 7 days convolutional window for a dataset
def conv_window(dataset: NormalizedDataset, width: int, label_columns: [str]) -> WindowGenerator:
  return WindowGenerator(
    dataset=dataset,
    input_width=width, 
    label_width=1, 
    shift=1,
    label_columns=label_columns,
  )

# %%
# Create convulutional windows for all normalized division datasets
div_conv_windows = [conv_window(dataset=ds,width=7,label_columns=["incidents"]) for ds in div_norms]

# %%
# Function to create an empty fresh multi-step DNN
def multi_step_dense_model() -> tf.keras.Model:
  return tf.keras.Sequential(
    [
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(units=32, activation="relu"),
      tf.keras.layers.Dense(units=32, activation="relu"),
      tf.keras.layers.Dense(units=1),
      tf.keras.layers.Reshape([1, -1]),
    ]
  )

# %%
# Creates a multi-step DNN model, fits and evaluates its performance against the give window
def multi_step_dnn_fit_eval(window: WindowGenerator) -> Perf:
  return compile_fit_eval(model=multi_step_dense_model(),window=window)

# %%
# Fit one multi-step DNN for each division
mutil_step_dnn_perfs = [multi_step_dnn_fit_eval(w) for w in div_conv_windows]
# Out:
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.0492 - mean_absolute_error: 0.7620 - val_loss: 0.8939 - val_mean_absolute_error: 0.7173
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8686 - mean_absolute_error: 0.6895 - val_loss: 0.8338 - val_mean_absolute_error: 0.6861
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8275 - mean_absolute_error: 0.6694 - val_loss: 0.8326 - val_mean_absolute_error: 0.6887
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8064 - mean_absolute_error: 0.6601 - val_loss: 0.8377 - val_mean_absolute_error: 0.6934
# Epoch 5/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7928 - mean_absolute_error: 0.6534 - val_loss: 0.8274 - val_mean_absolute_error: 0.6837
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7775 - mean_absolute_error: 0.6478 - val_loss: 0.8372 - val_mean_absolute_error: 0.6907
# Epoch 7/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7679 - mean_absolute_error: 0.6421 - val_loss: 0.8295 - val_mean_absolute_error: 0.6847
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8295 - mean_absolute_error: 0.6847
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 0.9819 - mean_absolute_error: 0.7394 - val_loss: 0.8295 - val_mean_absolute_error: 0.7254
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8399 - mean_absolute_error: 0.6867 - val_loss: 0.7988 - val_mean_absolute_error: 0.7126
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8058 - mean_absolute_error: 0.6755 - val_loss: 0.7749 - val_mean_absolute_error: 0.7002
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7820 - mean_absolute_error: 0.6649 - val_loss: 0.7742 - val_mean_absolute_error: 0.7023
# Epoch 5/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7635 - mean_absolute_error: 0.6581 - val_loss: 0.7793 - val_mean_absolute_error: 0.7053
# Epoch 6/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7502 - mean_absolute_error: 0.6519 - val_loss: 0.7875 - val_mean_absolute_error: 0.7114
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7875 - mean_absolute_error: 0.7114
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.1133 - mean_absolute_error: 0.8137 - val_loss: 0.9952 - val_mean_absolute_error: 0.7792
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9037 - mean_absolute_error: 0.7301 - val_loss: 0.9476 - val_mean_absolute_error: 0.7614
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8660 - mean_absolute_error: 0.7135 - val_loss: 0.9379 - val_mean_absolute_error: 0.7572
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8440 - mean_absolute_error: 0.7057 - val_loss: 0.9154 - val_mean_absolute_error: 0.7453
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8273 - mean_absolute_error: 0.6986 - val_loss: 0.9123 - val_mean_absolute_error: 0.7452
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8110 - mean_absolute_error: 0.6909 - val_loss: 0.9285 - val_mean_absolute_error: 0.7536
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7981 - mean_absolute_error: 0.6855 - val_loss: 0.9233 - val_mean_absolute_error: 0.7518
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9233 - mean_absolute_error: 0.7518
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.0745 - mean_absolute_error: 0.8157 - val_loss: 1.4954 - val_mean_absolute_error: 0.8895
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9390 - mean_absolute_error: 0.7641 - val_loss: 1.4941 - val_mean_absolute_error: 0.8929
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8948 - mean_absolute_error: 0.7443 - val_loss: 1.5083 - val_mean_absolute_error: 0.8992
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8691 - mean_absolute_error: 0.7340 - val_loss: 1.5039 - val_mean_absolute_error: 0.8969
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5039 - mean_absolute_error: 0.8969
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.2895 - mean_absolute_error: 0.8829 - val_loss: 1.0528 - val_mean_absolute_error: 0.8271
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9636 - mean_absolute_error: 0.7569 - val_loss: 0.9961 - val_mean_absolute_error: 0.7992
# Epoch 3/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.9204 - mean_absolute_error: 0.7384 - val_loss: 0.9912 - val_mean_absolute_error: 0.7972
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8967 - mean_absolute_error: 0.7278 - val_loss: 0.9688 - val_mean_absolute_error: 0.7853
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8762 - mean_absolute_error: 0.7187 - val_loss: 0.9736 - val_mean_absolute_error: 0.7877
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8621 - mean_absolute_error: 0.7139 - val_loss: 0.9643 - val_mean_absolute_error: 0.7830
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8491 - mean_absolute_error: 0.7059 - val_loss: 0.9688 - val_mean_absolute_error: 0.7846
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8335 - mean_absolute_error: 0.7015 - val_loss: 0.9626 - val_mean_absolute_error: 0.7813
# Epoch 9/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8221 - mean_absolute_error: 0.6966 - val_loss: 0.9560 - val_mean_absolute_error: 0.7772
# Epoch 10/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8091 - mean_absolute_error: 0.6903 - val_loss: 0.9559 - val_mean_absolute_error: 0.7774
# Epoch 11/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7987 - mean_absolute_error: 0.6856 - val_loss: 0.9721 - val_mean_absolute_error: 0.7857
# Epoch 12/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7873 - mean_absolute_error: 0.6803 - val_loss: 0.9514 - val_mean_absolute_error: 0.7731
# Epoch 13/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7750 - mean_absolute_error: 0.6748 - val_loss: 0.9543 - val_mean_absolute_error: 0.7760
# Epoch 14/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7675 - mean_absolute_error: 0.6704 - val_loss: 0.9585 - val_mean_absolute_error: 0.7773
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9585 - mean_absolute_error: 0.7773
# Epoch 1/20
# 40/40 [==============================] - 0s 7ms/step - loss: 1.0267 - mean_absolute_error: 0.8042 - val_loss: 0.9725 - val_mean_absolute_error: 0.7903
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.9339 - mean_absolute_error: 0.7623 - val_loss: 0.9386 - val_mean_absolute_error: 0.7736
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8929 - mean_absolute_error: 0.7445 - val_loss: 0.9258 - val_mean_absolute_error: 0.7645
# Epoch 4/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8615 - mean_absolute_error: 0.7333 - val_loss: 0.9187 - val_mean_absolute_error: 0.7634
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8365 - mean_absolute_error: 0.7208 - val_loss: 0.9151 - val_mean_absolute_error: 0.7600
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8193 - mean_absolute_error: 0.7149 - val_loss: 0.9136 - val_mean_absolute_error: 0.7571
# Epoch 7/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8057 - mean_absolute_error: 0.7081 - val_loss: 0.9147 - val_mean_absolute_error: 0.7576
# Epoch 8/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7840 - mean_absolute_error: 0.7006 - val_loss: 0.9204 - val_mean_absolute_error: 0.7573
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9204 - mean_absolute_error: 0.7573

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 80
plt.rcParams["figure.figsize"] = (10,8)

display(HTML(f"<h1>Division 1 Multi Step DNN Prediction Examples</h1>"))
div_conv_windows[0].plot(model=mutil_step_dnn_perfs[0].model, plot_col="incidents")
# Out:
# <h1>Division 1 Multi Step DNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>Division 2 Multi Step DNN Prediction Examples</h1>"))
div_conv_windows[1].plot(model=mutil_step_dnn_perfs[1].model, plot_col="incidents")
# Out:
# <h1>Division 2 Multi Step DNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>Division 6 Multi Step DNN Prediction Examples</h1>"))
div_conv_windows[5].plot(model=mutil_step_dnn_perfs[5].model, plot_col="incidents")
# Out:
# <h1>Division 6 Multi Step DNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>Single Step DNN Performance</h1>"))
display_perfs(mutil_step_dnn_perfs)
# Out:
# <h1>Single Step DNN Performance</h1>
# <h2>Division 1</h2>
# Validation perf: [0.8294818997383118, 0.6846962571144104]
# Test perf: [3.009925603866577, 0.7536496520042419]
# <hr />
# <h2>Division 2</h2>
# Validation perf: [0.7875221371650696, 0.7113552689552307]
# Test perf: [1.8551921844482422, 0.7742981314659119]
# <hr />
# <h2>Division 3</h2>
# Validation perf: [0.9233261942863464, 0.7518326640129089]
# Test perf: [1.646081805229187, 0.8158912658691406]
# <hr />
# <h2>Division 4</h2>
# Validation perf: [1.5039498805999756, 0.8969026803970337]
# Test perf: [2.0047836303710938, 0.935686469078064]
# <hr />
# <h2>Division 5</h2>
# Validation perf: [0.9584814310073853, 0.7772520184516907]
# Test perf: [1.3344001770019531, 0.8234002590179443]
# <hr />
# <h2>Division 6</h2>
# Validation perf: [0.9203878045082092, 0.7573465704917908]
# Test perf: [0.8785200119018555, 0.7575984597206116]
# <hr />

# %% [markdown]
# We can see that the model performs better than a single step window. There is still some overfitting and
# the overall performance is not much better than the baseline performance so there is still work to do.

# %% [markdown]
# # Models

# %% [markdown]
# ### CNN with a 7 day window

# %%
# Function that creates a new CNN model
def conv_model(width: int) -> tf.keras.Model:
  return  tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters=32, kernel_size=(width,), activation="relu"),
    tf.keras.layers.Dense(units=32, activation="relu"),
    tf.keras.layers.Dense(units=1),
  ])

# %%
# Creates a CNN model, fits and evaluates its performance against the give window
def cnn_fit_eval(window: WindowGenerator) -> Perf:
  return compile_fit_eval(model=conv_model(window.input_width),window=window)

# %%
# Fit one CNN model for each division
cnn_perfs = [cnn_fit_eval(w) for w in div_conv_windows]
# Out:
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.8707 - mean_absolute_error: 0.6824 - val_loss: 0.8363 - val_mean_absolute_error: 0.6902
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8206 - mean_absolute_error: 0.6617 - val_loss: 0.8394 - val_mean_absolute_error: 0.6906
# Epoch 3/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8001 - mean_absolute_error: 0.6533 - val_loss: 0.8531 - val_mean_absolute_error: 0.6993
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8531 - mean_absolute_error: 0.6993
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.8301 - mean_absolute_error: 0.6890 - val_loss: 0.7823 - val_mean_absolute_error: 0.7094
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7721 - mean_absolute_error: 0.6640 - val_loss: 0.7624 - val_mean_absolute_error: 0.6985
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7516 - mean_absolute_error: 0.6561 - val_loss: 0.7515 - val_mean_absolute_error: 0.6941
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7319 - mean_absolute_error: 0.6484 - val_loss: 0.7508 - val_mean_absolute_error: 0.6937
# Epoch 5/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.7187 - mean_absolute_error: 0.6445 - val_loss: 0.7366 - val_mean_absolute_error: 0.6848
# Epoch 6/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7072 - mean_absolute_error: 0.6380 - val_loss: 0.7505 - val_mean_absolute_error: 0.6940
# Epoch 7/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.6982 - mean_absolute_error: 0.6359 - val_loss: 0.7499 - val_mean_absolute_error: 0.6919
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7499 - mean_absolute_error: 0.6919
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9392 - mean_absolute_error: 0.7395 - val_loss: 0.9153 - val_mean_absolute_error: 0.7505
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8681 - mean_absolute_error: 0.7105 - val_loss: 0.8993 - val_mean_absolute_error: 0.7422
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8377 - mean_absolute_error: 0.6987 - val_loss: 0.9009 - val_mean_absolute_error: 0.7424
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8208 - mean_absolute_error: 0.6927 - val_loss: 0.9047 - val_mean_absolute_error: 0.7410
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9047 - mean_absolute_error: 0.7410
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9743 - mean_absolute_error: 0.7749 - val_loss: 1.4667 - val_mean_absolute_error: 0.8918
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8979 - mean_absolute_error: 0.7441 - val_loss: 1.4731 - val_mean_absolute_error: 0.8947
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8665 - mean_absolute_error: 0.7317 - val_loss: 1.4773 - val_mean_absolute_error: 0.8975
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4773 - mean_absolute_error: 0.8975
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9759 - mean_absolute_error: 0.7507 - val_loss: 0.8459 - val_mean_absolute_error: 0.7337
# Epoch 2/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.9119 - mean_absolute_error: 0.7287 - val_loss: 0.8365 - val_mean_absolute_error: 0.7278
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8898 - mean_absolute_error: 0.7219 - val_loss: 0.8265 - val_mean_absolute_error: 0.7199
# Epoch 4/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8745 - mean_absolute_error: 0.7148 - val_loss: 0.8234 - val_mean_absolute_error: 0.7175
# Epoch 5/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8574 - mean_absolute_error: 0.7090 - val_loss: 0.8365 - val_mean_absolute_error: 0.7248
# Epoch 6/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8438 - mean_absolute_error: 0.7031 - val_loss: 0.8369 - val_mean_absolute_error: 0.7250
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8369 - mean_absolute_error: 0.7250
# Epoch 1/20
# 40/40 [==============================] - 0s 8ms/step - loss: 0.9854 - mean_absolute_error: 0.7778 - val_loss: 0.8642 - val_mean_absolute_error: 0.7368
# Epoch 2/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8982 - mean_absolute_error: 0.7391 - val_loss: 0.8586 - val_mean_absolute_error: 0.7327
# Epoch 3/20
# 40/40 [==============================] - 0s 5ms/step - loss: 0.8677 - mean_absolute_error: 0.7281 - val_loss: 0.8596 - val_mean_absolute_error: 0.7332
# Epoch 4/20
# 40/40 [==============================] - 0s 6ms/step - loss: 0.8464 - mean_absolute_error: 0.7196 - val_loss: 0.8664 - val_mean_absolute_error: 0.7364
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8664 - mean_absolute_error: 0.7364

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 80
plt.rcParams["figure.figsize"] = (10,8)

display(HTML(f"<h1>Division 1 CNN Prediction Examples</h1>"))
div_conv_windows[0].plot(model=cnn_perfs[0].model, plot_col="incidents")
# Out:
# <h1>Division 1 CNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>Division 6 CNN Prediction Examples</h1>"))
div_conv_windows[5].plot(model=cnn_perfs[5].model, plot_col="incidents")
# Out:
# <h1>Division 6 CNN Prediction Examples</h1>

# %%
display(HTML(f"<h1>CNN Performance</h1>"))
display_perfs(cnn_perfs)
# Out:
# <h1>CNN Performance</h1>
# <h2>Division 1</h2>
# Validation perf: [0.8531364798545837, 0.6993339657783508]
# Test perf: [3.1648216247558594, 0.7886180281639099]
# <hr />
# <h2>Division 2</h2>
# Validation perf: [0.749946117401123, 0.6919184327125549]
# Test perf: [1.851232886314392, 0.7517566084861755]
# <hr />
# <h2>Division 3</h2>
# Validation perf: [0.9046618938446045, 0.7410361766815186]
# Test perf: [1.563806414604187, 0.7937734723091125]
# <hr />
# <h2>Division 4</h2>
# Validation perf: [1.4773166179656982, 0.8974512219429016]
# Test perf: [2.106823682785034, 0.9624388217926025]
# <hr />
# <h2>Division 5</h2>
# Validation perf: [0.8369261622428894, 0.7249876856803894]
# Test perf: [1.2381545305252075, 0.7800367474555969]
# <hr />
# <h2>Division 6</h2>
# Validation perf: [0.8664448261260986, 0.7363810539245605]
# Test perf: [0.8092851042747498, 0.704798698425293]
# <hr />

# %% [markdown]
# The performance is dropped a bit compared to multi-step DNN and there model seems to be overfit as well. Regularization and batch normalization, and
# hyper parameter tuning may help and that's exactly our next steps to explore.

# %%
# Set plot dpi and size
plt.rcParams["figure.dpi"] = 120
plt.rcParams["figure.figsize"] = (10,6)

all_perfs = [
  baseline_perfs[0],
  linear_perfs[0],
  single_step_dnn_perfs[0],
  mutil_step_dnn_perfs[0],
  cnn_perfs[0],
]

x = np.arange(len(all_perfs))
width = 0.3

metric_name = "mean_absolute_error"
metric_index = cnn_perfs[0].model.metrics_names.index("mean_absolute_error")
val_mae = [p.val[metric_index] for p in all_perfs]
test_mae = [p.test[metric_index] for p in all_perfs]

plt.bar(x - 0.17, val_mae, width, label="Validation")
plt.bar(x + 0.17, test_mae, width, label="Test")
xlabels = [
  "Baseline",
  "Linear",
  "Single Step DNN",
  "Multi step DNN",
  "CNN",
]
plt.xticks(ticks=x, labels=xlabels, rotation=45)
plt.ylabel('MAE (average over all outputs)')
plt.legend();
